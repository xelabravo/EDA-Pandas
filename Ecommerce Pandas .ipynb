# %% [markdown]
# # Ecommerce Pandas
# utilizar pandas para un EDA y sacar conclusiones al respecto.

# %%
import pandas as pd

# %%
ecom = pd.read_csv('Ecommerce Purchases')

# %%
#vemos la cabeza del dataframe.

# %%
ecom.head()
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
# ...

# %%
#A partir de aqui  ver columnas con valores NaN, sacar informacion estadistica con describe(), ver la longitud del dataframe

# %%
print ecom.info()
print ecom.describe()
print ecom.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
# Address             10000 non-null object
# Lot                 10000 non-null object
# AM or PM            10000 non-null object
# Browser Info        10000 non-null object
# Company             10000 non-null object
# Credit Card         10000 non-null int64
# CC Exp Date         10000 non-null object
# CC Security Code    10000 non-null int64
# CC Provider         10000 non-null object
# Email               10000 non-null object
# Job                 10000 non-null object
# IP Address          10000 non-null object
# Language            10000 non-null object
# Purchase Price      10000 non-null float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 1.1+ MB
# None
#         Credit Card  CC Security Code  Purchase Price
# count  1.000000e+04      10000.000000    10000.000000
# mean   2.341374e+15        907.217800       50.347302
# ...

# %%
#vemos como no tenemos ningun dato como NaN,el prcio medio está en 50.Viendo la tabla describe no observamos ningun outlier.

# %%
#aunque ya tenemos la media por ejemplo en precios podemos sacarlo con:
ecom['Purchase Price'].mean()
# Out:
# 50.34730200000025

# %%
#una consulta que se puede hacer con pandas por ejemplo es ver la cantidad de personas que utilizan la web en un
#determinado lenguaje.En este caso el español 'es'
ecom[ecom['Language']=='es'] ['Language'].count()
# Out:
# 1095

# %%
#ver los tipos de trabajo que hay y cuales son los que mas aparecen
ecom['Job'].value_counts()
# Out:
# Interior and spatial designer                                  31
# Lawyer                                                         30
# Social researcher                                              28
# Designer, jewellery                                            27
# Research officer, political party                              27
# Purchasing manager                                             27
# Special educational needs teacher                              26
# Social worker                                                  26
# Designer, fashion/clothing                                     26
# Charity fundraiser                                             26
# Dietitian                                                      26
# Engineer, water                                                25
# Radio broadcast assistant                                      25
# Psychologist, clinical                                         25
# ...

# %%
#Vemos los tipos de trabajos que hay en el data set si queremos obtener el dataframe solo con los trabajos ej Toxicologist
#seria.
ecom[ecom['Job']=='Toxicologist']
# Out:
#                                                 Address    Lot AM or PM  \
# 1252  8881 Smith Street Suite 111\nAudreychester, NJ...  14 vC       PM
# 1490  192 Dunn Fords Suite 742\nPort Molly, WV 55598...  38 Mm       PM
# 1997  38122 Stewart Shores Suite 692\nJacobburgh, NY...  95 eO       PM
# 2292  77814 Dunlap Grove Suite 342\nCastanedaview, M...  65 ym       AM
# 2558       59680 Phillips Glens\nNorth Philip, MI 76680  38 Cm       AM
# 4732      64519 Jade Spur\nLake Lisastad, NH 45780-2136  52 bp       AM
# 5014  02433 Cherry Keys\nSouth Williamland, NJ 83184...  86 Zg       PM
# 6581  1395 Norris Road Apt. 751\nLake Kathryn, NH 51...  24 eL       AM
# 6942       64133 Lane Spurs\nSouth Nancyburgh, CO 97773  65 LR       AM
#
#                                            Browser Info  \
# 1252  Mozilla/5.0 (Windows NT 5.01; sl-SI; rv:1.9.0....
# 1490  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_9 ...
# 1997  Opera/8.29.(X11; Linux i686; en-US) Presto/2.9...
# ...

# %%
#otro caso seria ver las distintas compras que se hacen por la mañana como por la tarde

# %%
ecom['AM or PM'].value_counts()
# Out:
# PM    5068
# AM    4932
# Name: AM or PM, dtype: int64

# %%
#caso especifico para ver con que tajeta se compro alguien lo mas caro de la pagina

# %%
ecom[(ecom['CC Provider']=='American Express') & (ecom['Purchase Price']>95)].count()
# Out:
# Address             39
# Lot                 39
# AM or PM            39
# Browser Info        39
# Company             39
# Credit Card         39
# CC Exp Date         39
# CC Security Code    39
# CC Provider         39
# Email               39
# Job                 39
# IP Address          39
# Language            39
# Purchase Price      39
# dtype: int64

# %%
ecom['Job'].value_counts().head(5)
# Out:
# Interior and spatial designer        31
# Lawyer                               30
# Social researcher                    28
# Designer, jewellery                  27
# Research officer, political party    27
# Name: Job, dtype: int64

# %%
#siguiendo con las tarjetas de credito vamos a comprobar las que expiran en el año 2018 el formato es xx/xx. para coger el 
#3 en adelante sera datos[3:]#ecom['CC Exp Date'].iloc[0][3:]
ecom[ecom['CC Exp Date'].apply(lambda(x): x[3:])=='18']
# Out:
#                                                 Address    Lot AM or PM  \
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 24                Unit 3046 Box 3197\nDPO AE 61496-4172  62 Ac       AM
# 37           86777 Mary Crescent\nCarloshaven, KY 48326  10 LL       AM
# 58    26217 James Station Apt. 999\nNatalieland, VT ...  95 aS       PM
# 74    189 Washington Dale Suite 864\nAngelaburgh, MO...  04 bK       PM
# 88      498 Thomas Spring\nMccormickport, IL 83795-1427  55 bP       PM
# 89    7506 Benjamin Corner Suite 959\nWest Joseph, G...  37 gk       AM
# 90          431 Bowen Lights\nFergusonborough, MH 01362  31 tG       AM
# 92                Unit 9659 Box 0618\nDPO AA 00377-5360  37 jN       AM
# 93         96321 Brandon Motorway\nBerryshire, AL 84052  54 hT       AM
# 95    4445 Christopher Well Apt. 053\nRonaldton, KS ...  33 Uu       PM
# 114               Unit 0282 Box 9769\nDPO AP 05162-2277  72 zO       AM
# ...

# %%
#si quiero saber la suma total de personas seria con el comando sum() 995 personas tienen que solicitar una nueva tarjeta
# a su entidad bancaria.
sum(ecom['CC Exp Date'].apply(lambda(x): x[3:])=='18')
# Out:
# 995

# %%
#ver el email que host son los mas polulares
#aqui no puedo hacer un value counts ya que no me saldria los valores de cada host separados 
#necesario una funcion que separe el email.

#ejemplo1 = ecom['Email'].iloc[0]
#ejemplo1.split('@')---->['pdunlap', 'yahoo.com']
#ejemplo1.split('@')[1]---->'yahoo.com'
#ejemplo1 = ecom['Email'].iloc[0]
#mas_sep = ejemplo1.split('@')[1]
#mas_sep.split('.com')[0]
ecom['Email'].apply(lambda x: x.split('@')[1]).value_counts().head()
# Out:
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# Name: Email, dtype: int64

# %%
#graficas 
cr =
